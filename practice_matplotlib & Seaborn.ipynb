# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
x = np.arange(0,10)
y= np.arange(11,21)

# %%
plt.scatter(x,y, c='g')
#plt.show()
plt.plot(x,y,'r--')
plt.xlabel('x axis')
plt.ylabel('y lable')
plt.title('graph')
plt.savefig('testfig.jpg')

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'r--')
plt.subplot(2,2,2)
plt.plot(x,y,'r--')
plt.subplot(2,2,3)
plt.plot(x,y,'r--')
plt.subplot(2,2,4)
plt.plot(x,y,'r--')

# %%
y = 3*x*x+5

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'r--')
plt.subplot(2,2,2)
plt.plot(x,y,'g*-')

# %%
np.pi
# Out:
# 3.141592653589793

# %%
x = np.arange(0,4*np.pi,0.1)
#y = np.arange(0,10)
y= np.sin(x)

# %%
#plt.subplot(2,2,1)
plt.plot(x,y,'r--')

# %%
plt.subplot(2,1,1)
plt.plot(x,y,'r--')
plt.subplot(2,1,2)
plt.plot(x,y,'g--')

# %%
x = [2,8,10]
y= [3,4,5]
x1 = [4,6,8]
y1= [7,2,9]
plt.bar(x,y)
plt.bar(x1,y1)
# Out:
# <BarContainer object of 3 artists>

# %%
data = np.random.normal(1,5,50)

# %%
plt.boxplot(data, vert=True,patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ff34ad21940>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ff3497d9b50>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x7ff3493a6ac0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff34afe2760>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff34afe2190>],
#  'means': []}

# %%
print(data)
# Out:
# [-1.49548153e+01 -2.72171566e+00 -2.10753893e+00  1.13660824e+01
#  -3.53712392e+00 -3.96050692e+00  2.65567868e-01 -7.87108858e-02
#  -6.07998862e+00  4.49960671e+00  7.46490372e-02  2.23898369e-01
#   2.13446407e+00 -7.09060148e-01 -2.90031116e-01 -2.69745434e+00
#  -3.54998486e+00 -4.07006701e-02 -2.09887475e-01  4.96099023e+00
#  -4.16328888e+00  1.16206726e+00  8.49679435e+00  1.06070528e+00
#  -5.78007493e-01  4.15957781e+00 -2.08657954e+00 -4.16548131e-04
#   1.19112410e+00  4.10519190e-01 -1.72718605e+00  2.76707809e+00
#  -1.65851277e+00  6.22843835e-01  6.13067298e+00  3.26634449e+00
#   4.35596317e+00  3.03141485e+00  4.95106488e+00 -2.12736901e+00
#   4.12435850e-01  1.35991675e+01  7.77831892e+00 -2.14035858e+00
#   5.12913138e+00  2.84629338e+00 -6.52195257e-01  5.52115255e-01
#   4.44846621e+00 -2.89404859e+00]

# %%
plt.pie([295,210,70],labels=['orange','apple','banana'],colors= ['red','yellow','green'], 
        explode= [0,0,0.2],autopct='%0.2f%%',shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7ff348251730>,
# ...
#  [Text(-0.04506235965308221, 1.0990766050382914, 'orange'),
#   Text(-0.368367683088773, -1.0364869753430621, 'apple'),
#   Text(1.2060766516416221, -0.4851588506509316, 'banana')],
#  [Text(-0.024579468901681206, 0.5994963300208862, '51.30%'),
#   Text(-0.2009278271393307, -0.5653565320053066, '36.52%'),
#   Text(0.7422010163948445, -0.2985592927082656, '12.17%')])

# %%
import seaborn as sns

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# correlartion only consider numerical variable not categorical variable
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x = 'tip', y= 'total_bill', data=df , kind='hex', )

# %%
sns.pairplot(df, hue='sex')

# %%
sns.pairplot(df, hue='smoker')

# %%
df['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
sns.distplot(df['total_bill'])
# Out:
# /Library/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.displot(df['tip'])

# %%
sns.countplot(x='sex', data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(y='day', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='day'>

# %%
sns.barplot(x='sex', y='tip', data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(data= df)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='sex',y='total_bill', data= df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.violinplot(x='sex',y='total_bill', data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.violinplot( data=df)
# Out:
# <AxesSubplot:>
